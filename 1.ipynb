# %%
import csv
import numpy as np
import statsmodels.api as sm

X = np.loadtxt("DATAS.csv", skiprows=1, delimiter=",", usecols=(1,2,3,4))
X
# Out:
# array([[2.65430000e+05, 3.50000000e+00, 4.80000000e+00, 1.00000000e+00],
#        [2.57163000e+05, 3.50000000e+00, 4.90000000e+00, 1.00000000e+00],
#        [3.21951000e+05, 3.50000000e+00, 5.00000000e+00, 1.00000000e+00],
#        [2.49523000e+05, 3.50000000e+00, 5.10000000e+00, 1.00000000e+00],
#        [2.40226000e+05, 3.50000000e+00, 4.80000000e+00, 1.00000000e+00],
#        [2.52132000e+05, 3.50000000e+00, 4.90000000e+00, 1.00000000e+00],
#        [2.24371000e+05, 3.50000000e+00, 4.80000000e+00, 1.00000000e+00],
#        [2.76166000e+05, 3.50000000e+00, 4.90000000e+00, 1.00000000e+00],
#        [2.18218000e+05, 3.50000000e+00, 5.00000000e+00, 1.00000000e+00],
#        [2.08977000e+05, 3.50000000e+00, 4.90000000e+00, 1.00000000e+00],
#        [2.47635000e+05, 3.50000000e+00, 4.70000000e+00, 1.00000000e+00],
#        [1.86797000e+05, 3.63095238e+00, 4.70000000e+00, 1.25000000e+00],
#        [2.69913000e+05, 3.75000000e+00, 4.70000000e+00, 1.25000000e+00],
# ...

# %% [raw]
# DPRIME, UNRATE, INTDSRUSM193N = np.hsplit(X,3)
